# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Project import Project

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

from Scripts.TrainingUtils import Trainer, autoencoder_basic_training_routine, autoencoder_basic_validation_routine
from Scripts.data.TsinghuaDataset import TsinghuaDataset
from Scripts.data.Dataloader import Dataloader
from Models import Autoencoder

from torchsummary import summary

ngpu = 1; device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# %% [markdown]
# ***

# %%
BATCH_SIZE = 64
SIGNAL_LENGTH = 250
NUM_SUBJECTS = 5
dataset = Dataset('benchmark', Project, SIGNAL_LENGTH, individuals = [*range(1, NUM_SUBJECTS + 1)])
dataloaders, _ = Dataloader(dataset, BATCH_SIZE)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3bfa57ae74e9> in <module>
#       2 SIGNAL_LENGTH = 250
#       3 NUM_SUBJECTS = 5
# ----> 4 dataset = Dataset('benchmark', Project, SIGNAL_LENGTH, individuals = [*range(1, NUM_SUBJECTS + 1)])
#       5 dataloaders, _ = Dataloader(dataset, BATCH_SIZE)
#
# ~\Documents\GitHub\ICDeepLearning\Scripts\data\TsinghuaDataset.py in __init__(self, dataset, Project, sequence_length, classes, individuals)
#      25             self.blocks = range(1, 4 + 1)
#      26
# ---> 27         self.init_dataset()
#      28
#      29     def __len__(self):
#
# ~\Documents\GitHub\ICDeepLearning\Scripts\data\TsinghuaDataset.py in init_dataset(self)
#      42
#      43     def init_dataset(self):
# ---> 44         file_names = ["SS{}_{}_{}.csv".format(i, b, s) for (i, b, s) in product(self.individuals, self.blocks, self.segments)]
#      45         self.samples = [(self.read_data(self.data_path / c / file), int(c) - 1) for c, file in product(self.classes, file_names)]
#
# AttributeError: 'Dataset' object has no attribute 'individuals'

# %% [markdown]
# ***

# %%
from Models.Autoencoder import Autoencoder

# %%
model = Autoencoder(kernel_n = 1, stride = 2, n_feature_maps = 1).to(device)

# %%
summary(model, (1, 64, int(SIGNAL_LENGTH)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 1, 64, 125]               4
#               ReLU-2           [-1, 1, 64, 125]               0
#        BatchNorm2d-3           [-1, 1, 64, 125]               2
#    ConvTranspose2d-4           [-1, 1, 64, 250]               4
# ================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.06
# Forward/backward pass size (MB): 0.31
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.37
# ----------------------------------------------------------------

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 1e-3, momentum = 0.9)
# optimizer = optim.Adam(model.parameters(), lr = 1e-3, weight_decay = 1e-5)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 5, gamma = 0.5)

# %%
T = Trainer(problem_type = 'regression', training_routine = autoencoder_basic_training_routine, validation_routine = autoencoder_basic_validation_routine)

# %%
model, training_info = T.train(model, dataloaders, criterion, optimizer)
# Out:
# Epoch    Stage       Loss
#
# 1/10     Training    0.60
#          Validation  0.09
# 2/10     Training    0.29
#          Validation  0.06
# 3/10     Training    0.23
#          Validation  0.05
# 4/10     Training    0.19
#          Validation  0.04
# 5/10     Training    0.14
#          Validation  0.03
# 6/10     Training    0.11
#          Validation  0.03
# 7/10     Training    0.10
#          Validation  0.03
# 8/10     Training    0.10
#          Validation  0.03
# 9/10     Training    0.10
#          Validation  0.03
# 10/10    Training    0.10
#          Validation  0.03
# Training complete in 0m 20s
# Best Validation Loss: 0.03

# %%
samples = np.asarray([sample[0].flatten().numpy() for sample in dataloaders['val'].dataset])
targets = np.asarray([sample[1] for sample in dataloaders['val'].dataset])

# %%
tsne = TSNE(n_components = 2, verbose = 1, perplexity = 40)
pca = PCA(n_components =  2000)

# %%
pca_result = pca.fit_transform(samples)
print(np.sum(pca.explained_variance_ratio_))
# Out:
# 0.94575363

# %%
tsne_results = tsne.fit_transform(pca_result)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 6120 samples in 2.829s...
# [t-SNE] Computed neighbors for 6120 samples in 153.912s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6120
# [t-SNE] Computed conditional probabilities for sample 2000 / 6120
# [t-SNE] Computed conditional probabilities for sample 3000 / 6120
# [t-SNE] Computed conditional probabilities for sample 4000 / 6120
# [t-SNE] Computed conditional probabilities for sample 5000 / 6120
# [t-SNE] Computed conditional probabilities for sample 6000 / 6120
# [t-SNE] Computed conditional probabilities for sample 6120 / 6120
# [t-SNE] Mean sigma: 27.613284
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.980026
# [t-SNE] KL divergence after 1000 iterations: 2.789610

# %%
df = pd.DataFrame()
df['one'] = tsne_results[:, 0]
df['two'] = tsne_results[:, 1]
df['y']   = targets

# %%
import seaborn as sns

# %%
set(targets)
# Out:
# {0, 1, 2, 3, 4}

# %%
plt.figure(figsize = (16, 10))
sns.scatterplot(
    x = 'one', y = 'two',
    hue = 'y',
    palette = sns.color_palette('hls', 5),
    data = df,
    legend = 'full',
    alpha = 0.3
)
# Out:
# NumExpr defaulting to 4 threads.
# <AxesSubplot:xlabel='one', ylabel='two'>

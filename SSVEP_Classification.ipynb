# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Project import Project

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from Scripts.data.DataLoading import get_image_dataloaders, get_image_dataset
from Scripts.neuralnets.NNPreinstalledModelSelection import *
from Scripts.neuralnets.NNTrainingUtils import train, kfold_train

# %%
ngpu = 1; device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# %% [markdown]
# ***

# %%
preprocessing = 'cca'
signal_length = '512'
fig_type = 'rp'
dataloaders, dataset_sizes = get_image_dataloaders(Project, preprocessing, signal_length, fig_type, batch_size = 16)

# %%
model_type = 'resnet'; model_size = '50'; num_classes = 5; model_name = model_type + model_size
model = model_selection(model_name, num_classes, pretrained = False).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 10, gamma = 0.1)

# %%
model, stats = train(Project, model, dataloaders, dataset_sizes, criterion, optimizer, scheduler, num_epochs = 15)
# Out:
# [17/Sep/2020 16:46:17] INFO - Epoch  Stage       Loss    Accuracy
#
# [17/Sep/2020 16:48:40] INFO - 1/15   Training    1.64    0.23
# [17/Sep/2020 16:49:15] INFO -        Validation  1.64    0.24
# [17/Sep/2020 16:51:35] INFO - 2/15   Training    1.64    0.23
# [17/Sep/2020 16:52:10] INFO -        Validation  1.64    0.24
# [17/Sep/2020 16:54:30] INFO - 3/15   Training    1.64    0.22
# [17/Sep/2020 16:55:07] INFO -        Validation  1.64    0.24
# [17/Sep/2020 16:57:36] INFO - 4/15   Training    1.64    0.23
# [17/Sep/2020 16:58:12] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:00:34] INFO - 5/15   Training    1.64    0.23
# [17/Sep/2020 17:01:09] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:03:21] INFO - 6/15   Training    1.64    0.23
# [17/Sep/2020 17:03:57] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:06:16] INFO - 7/15   Training    1.64    0.23
# [17/Sep/2020 17:06:49] INFO -        Validation  1.64    0.25
# [17/Sep/2020 17:09:08] INFO - 8/15   Training    1.64    0.23
# [17/Sep/2020 17:09:44] INFO -        Validation  1.65    0.24
# [17/Sep/2020 17:12:11] INFO - 9/15   Training    1.64    0.23
# [17/Sep/2020 17:12:48] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:15:14] INFO - 10/15  Training    1.64    0.23
# [17/Sep/2020 17:15:51] INFO -        Validation  1.63    0.24
# [17/Sep/2020 17:18:14] INFO - 11/15  Training    1.64    0.23
# [17/Sep/2020 17:18:52] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:21:18] INFO - 12/15  Training    1.64    0.23
# [17/Sep/2020 17:21:54] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:24:22] INFO - 13/15  Training    1.64    0.23
# [17/Sep/2020 17:25:01] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:27:33] INFO - 14/15  Training    1.64    0.23
# [17/Sep/2020 17:28:12] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:30:47] INFO - 15/15  Training    1.64    0.23
# [17/Sep/2020 17:31:24] INFO -        Validation  1.64    0.24
# [17/Sep/2020 17:31:24] INFO - Training complete in 45m 6s
# [17/Sep/2020 17:31:24] INFO - Best Validation Accuracy: 0.25
# [17/Sep/2020 17:31:24] INFO - Best Validation Loss: 1.64

# %% [markdown]
# ***

# %%
preprocessing = 'cca'
signal_length = '512'
fig_type = 'rp'
dataset = get_image_dataset(Project, preprocessing, signal_length, fig_type)

# %%
model_type = 'resnet'; model_size = '50'; num_classes = 5; model_name = model_type + model_size
model = model_selection(model_name, num_classes).to(device)

# %%
optimizer = optim.SGD(model.parameters(), lr = 0.001, momentum = 0.4)
criterion = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 7, gamma = 0.1)

# %%
model, stats = kfold_train(Project, model, dataset, criterion, optimizer, num_epochs = 20, num_folds = 5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-cd2111fc3986> in <module>
# ----> 1 model, stats = kfold_train(Project, model, dataset, criterion, optimizer, num_epochs = 20, num_folds = 5)
#
# ~\Documents\GitHub\ICDeepLearning\Scripts\neuralnets\NNTrainingUtils.py in kfold_train(project, model, dataset, criterion, optimizer, scheduler, num_folds, batch_size, save_model, num_epochs)
#     168
#     169         since = time.time()
# --> 170         model, stats = train(project, model, dataloaders, dataset_size, criterion, optimizer, scheduler, num_epochs, logger = logger, kfold = True)
#     171         time_elapsed = time.time() - since
#     172
#
# ~\Documents\GitHub\ICDeepLearning\Scripts\neuralnets\NNTrainingUtils.py in train(project, model, dataloaders, dataset_size, criterion, optimizer, scheduler, num_epochs, logger, kfold)
#      85             cumulative_hits = 0
#      86
# ---> 87             for inputs, labels in dataloaders[phase]:
#      88                 inputs = inputs.to(device)
#      89                 labels = labels.to(device)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     344     def __next__(self):
#     345         index = self._next_index()  # may raise StopIteration
# --> 346         data = self.dataset_fetcher.fetch(index)  # may raise StopIteration
#     347         if self.pin_memory:
#     348             data = _utils.pin_memory.pin_memory(data)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataset.py in __getitem__(self, idx)
#     254
#     255     def __getitem__(self, idx):
# --> 256         return self.dataset[self.indices[idx]]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\torchvision\datasets\folder.py in __getitem__(self, index)
#     136         """
#     137         path, target = self.samples[index]
# --> 138         sample = self.loader(path)
#     139         if self.transform is not None:
#     140             sample = self.transform(sample)
#
# ~\Anaconda3\lib\site-packages\torchvision\datasets\folder.py in default_loader(path)
#     172         return accimage_loader(path)
#     173     else:
# --> 174         return pil_loader(path)
#     175
#     176
#
# ~\Anaconda3\lib\site-packages\torchvision\datasets\folder.py in pil_loader(path)
#     155     with open(path, 'rb') as f:
#     156         img = Image.open(f)
# --> 157         return img.convert('RGB')
#     158
#     159
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in convert(self, mode, matrix, dither, palette, colors)
#     900         """
#     901
# --> 902         self.load()
#     903
#     904         if not mode and self.mode == "P":
#
# ~\Anaconda3\lib\site-packages\PIL\ImageFile.py in load(self)
#     259
#     260                             b = b + s
# --> 261                             n, err_code = decoder.decode(b)
#     262                             if n < 0:
#     263                                 break
#
# KeyboardInterrupt:

# %% [markdown]
# ***

# %%
dataType = '128'
data = pd.read_csv('SSVEPDataset_'+dataType+'.csv')
dataset = SSVEPDataset(data, int(dataType))

batchSize = 64
dataloaders, datasetsSizes = SSVEPDataloaders(dataset, batchSize)
# example = next(iter(dataloaders['train']))['series']

device = torch.device("cuda:0" if (torch.cuda.is_available()) else "cpu")
# device = 'cpu'
print(datasetsSizes)
# Out:
# {'train': 8716, 'val': 2178}

# %%
model = model_selection('resnet50', 5)
model.conv1 = nn.Conv2d(1, 64, kernel_size = (7, 7), stride = (2, 2), padding = (3, 3), bias = False)
model = model.to(device)
optimizer = optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)
criterion = nn.CrossEntropyLoss()
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 7, gamma = 0.1)

# %%
model, _, _ = kfold_train(model, dataset, criterion, optimizer, num_epochs = 25, num_folds = 5)
# Out:
# Fold 0
# --
# Epoch 1/25
# -----
# Stage: train
# Loss: 1.7669 - Accuracy: 0.2140
# Stage: val
# Loss: 1.6186 - Accuracy: 0.2203
# --
# Epoch 2/25
# -----
# Stage: train
# Loss: 1.6771 - Accuracy: 0.2185
# Stage: val
# Loss: 1.6174 - Accuracy: 0.2474
# --
# Epoch 3/25
# -----
# Stage: train
# Loss: 1.6642 - Accuracy: 0.2154
# Stage: val
# Loss: 1.6376 - Accuracy: 0.2001
# --
# Epoch 4/25
# -----
# Stage: train
# Loss: 1.6591 - Accuracy: 0.2073
# Stage: val
# Loss: 1.7865 - Accuracy: 0.2313
# --
# Epoch 5/25
# -----
# Stage: train
# Loss: 1.6449 - Accuracy: 0.2165
# Stage: val
# Loss: 1.7841 - Accuracy: 0.2116
# --
# Epoch 6/25
# -----
# Stage: train
# Loss: 1.6414 - Accuracy: 0.2193
# Stage: val
# Loss: 1.6316 - Accuracy: 0.2432
# --
# Epoch 7/25
# -----
# Stage: train
# Loss: 1.6350 - Accuracy: 0.2263
# Stage: val
# Loss: 1.7066 - Accuracy: 0.2437
# --
# Epoch 8/25
# -----
# Stage: train
# Loss: 1.6429 - Accuracy: 0.2174
# Stage: val
# Loss: 1.6712 - Accuracy: 0.2331
# --
# Epoch 9/25
# -----
# Stage: train
# Loss: 1.6379 - Accuracy: 0.2189
# Stage: val
# Loss: 1.6414 - Accuracy: 0.1955
# --
# Epoch 10/25
# -----
# Stage: train
# Loss: 1.6329 - Accuracy: 0.2225
# Stage: val
# Loss: 1.6899 - Accuracy: 0.2249
# --
# Epoch 11/25
# -----
# Stage: train
# Loss: 1.6307 - Accuracy: 0.2127
# Stage: val
# Loss: 1.5874 - Accuracy: 0.2538
# --
# Epoch 12/25
# -----
# Stage: train
# Loss: 1.6217 - Accuracy: 0.2264
# Stage: val
# Loss: 1.6161 - Accuracy: 0.2308
# --
# Epoch 13/25
# -----
# Stage: train
# Loss: 1.6214 - Accuracy: 0.2240
# Stage: val
# Loss: 1.6626 - Accuracy: 0.2226
# --
# Epoch 14/25
# -----
# Stage: train
# Loss: 1.6161 - Accuracy: 0.2330
# Stage: val
# Loss: 1.6137 - Accuracy: 0.2051
# --
# Epoch 15/25
# -----
# Stage: train
# Loss: 1.6068 - Accuracy: 0.2342
# Stage: val
# Loss: 1.6065 - Accuracy: 0.2377
# --
# Epoch 16/25
# -----
# Stage: train
# Loss: 1.6154 - Accuracy: 0.2314
# Stage: val
# Loss: 1.6215 - Accuracy: 0.2024
# --
# Epoch 17/25
# -----
# Stage: train
# Loss: 1.6210 - Accuracy: 0.2171
# Stage: val
# Loss: 2.1715 - Accuracy: 0.2129
# --
# Epoch 18/25
# -----
# Stage: train
# Loss: 1.6134 - Accuracy: 0.2260
# Stage: val
# Loss: 1.6520 - Accuracy: 0.2285
# --
# Epoch 19/25
# -----
# Stage: train
# Loss: 1.6124 - Accuracy: 0.2201
# Stage: val
# Loss: 1.6647 - Accuracy: 0.2483
# --
# Epoch 20/25
# -----
# Stage: train
# Loss: 1.6109 - Accuracy: 0.2213
# Stage: val
# Loss: 1.6895 - Accuracy: 0.2336
# --
# Epoch 21/25
# -----
# Stage: train
# Loss: 1.6073 - Accuracy: 0.2320
# Stage: val
# Loss: 1.7550 - Accuracy: 0.2290
# --
# Epoch 22/25
# -----
# Stage: train
# Loss: 1.6116 - Accuracy: 0.2235
# Stage: val
# Loss: 1.7885 - Accuracy: 0.2281
# --
# Epoch 23/25
# -----
# Stage: train
# Loss: 1.6050 - Accuracy: 0.2221
# Stage: val
# Loss: 1.6459 - Accuracy: 0.2405
# --
# Epoch 24/25
# -----
# Stage: train
# Loss: 1.6030 - Accuracy: 0.2293
# Stage: val
# Loss: 1.6153 - Accuracy: 0.2432
# --
# Epoch 25/25
# -----
# Stage: train
# Loss: 1.6064 - Accuracy: 0.2239
# Stage: val
# Loss: 1.6047 - Accuracy: 0.2391
# Best validation accuracy: 0.253786
#
# Fold 1
# --
# Epoch 1/25
# -----
# Stage: train
# Loss: 1.7503 - Accuracy: 0.2166
# Stage: val
# Loss: 2.3396 - Accuracy: 0.2221
# --
# Epoch 2/25
# -----
# Stage: train
# Loss: 1.6569 - Accuracy: 0.2271
# Stage: val
# Loss: 1.6669 - Accuracy: 0.2028
# --
# Epoch 3/25
# -----
# Stage: train
# Loss: 1.6435 - Accuracy: 0.2148
# Stage: val
# Loss: 1.9077 - Accuracy: 0.2212
# --
# Epoch 4/25
# -----
# Stage: train
# Loss: 1.6290 - Accuracy: 0.2294
# Stage: val
# Loss: 1.7558 - Accuracy: 0.2285
# --
# Epoch 5/25
# -----
# Stage: train
# Loss: 1.6353 - Accuracy: 0.2287
# Stage: val
# Loss: 1.9319 - Accuracy: 0.2180
# --
# Epoch 6/25
# -----
# Stage: train
# Loss: 1.6230 - Accuracy: 0.2350
# Stage: val
# Loss: 1.7146 - Accuracy: 0.2162
# --
# Epoch 7/25
# -----
# Stage: train
# Loss: 1.6158 - Accuracy: 0.2394
# Stage: val
# Loss: 1.6665 - Accuracy: 0.2377
# --
# Epoch 8/25
# -----
# Stage: train
# Loss: 1.6284 - Accuracy: 0.2274
# Stage: val
# Loss: 1.6565 - Accuracy: 0.2409
# --
# Epoch 9/25
# -----
# Stage: train
# Loss: 1.6031 - Accuracy: 0.2423
# Stage: val
# Loss: 1.5915 - Accuracy: 0.2584
# --
# Epoch 10/25
# -----
# Stage: train
# Loss: 1.5930 - Accuracy: 0.2429
# Stage: val
# Loss: 1.5982 - Accuracy: 0.2611
# --
# Epoch 11/25
# -----
# Stage: train
# Loss: 1.5692 - Accuracy: 0.2613
# Stage: val
# Loss: 1.8099 - Accuracy: 0.2212
# --
# Epoch 12/25
# -----
# Stage: train
# Loss: 1.5707 - Accuracy: 0.2530
# Stage: val
# Loss: 1.5512 - Accuracy: 0.2620
# --
# Epoch 13/25
# -----
# Stage: train
# Loss: 1.5536 - Accuracy: 0.2703
# Stage: val
# Loss: 1.8494 - Accuracy: 0.2607
# --
# Epoch 14/25
# -----
# Stage: train
# Loss: 1.5562 - Accuracy: 0.2737
# Stage: val
# Loss: 1.6221 - Accuracy: 0.3199
# --
# Epoch 15/25
# -----
# Stage: train
# Loss: 1.5454 - Accuracy: 0.2823
# Stage: val
# Loss: 1.5928 - Accuracy: 0.2960
# --
# Epoch 16/25
# -----
# Stage: train
# Loss: 1.5463 - Accuracy: 0.2853
# Stage: val
# Loss: 1.5650 - Accuracy: 0.2859
# --
# Epoch 17/25
# -----
# Stage: train
# Loss: 1.5500 - Accuracy: 0.2760
# Stage: val
# Loss: 1.6090 - Accuracy: 0.3066
# --
# Epoch 18/25
# -----
# Stage: train
# Loss: 1.4998 - Accuracy: 0.3251
# Stage: val
# Loss: 1.4682 - Accuracy: 0.3731
# --
# Epoch 19/25
# -----
# Stage: train
# Loss: 1.4581 - Accuracy: 0.3493
# Stage: val
# Loss: 1.4735 - Accuracy: 0.3786
# --
# Epoch 20/25
# -----
# Stage: train
# Loss: 1.4565 - Accuracy: 0.3582
# Stage: val
# Loss: 1.3829 - Accuracy: 0.4126
# --
# Epoch 21/25
# -----
# Stage: train
# Loss: 1.2928 - Accuracy: 0.4649
# Stage: val
# Loss: 1.2167 - Accuracy: 0.5278
# --
# Epoch 22/25
# -----
# Stage: train
# Loss: 1.1671 - Accuracy: 0.5314
# Stage: val
# Loss: 2.0893 - Accuracy: 0.4318
# --
# Epoch 23/25
# -----
# Stage: train
# Loss: 1.1813 - Accuracy: 0.5303
# Stage: val
# Loss: 1.3997 - Accuracy: 0.4580
# --
# Epoch 24/25
# -----
# Stage: train
# Loss: 1.1476 - Accuracy: 0.5517
# Stage: val
# Loss: 1.0698 - Accuracy: 0.6108
# --
# Epoch 25/25
# -----
# Stage: train
# Loss: 1.0290 - Accuracy: 0.6055
# Stage: val
# Loss: 0.9739 - Accuracy: 0.6485
# Best validation accuracy: 0.648463
#
# Fold 2
# --
# Epoch 1/25
# -----
# Stage: train
# Loss: 1.7613 - Accuracy: 0.2190
# Stage: val
# Loss: 1.6424 - Accuracy: 0.2106
# --
# Epoch 2/25
# -----
# Stage: train
# Loss: 1.6700 - Accuracy: 0.2184
# Stage: val
# Loss: 2.0153 - Accuracy: 0.2263
# --
# Epoch 3/25
# -----
# Stage: train
# Loss: 1.6521 - Accuracy: 0.2270
# Stage: val
# Loss: 1.7703 - Accuracy: 0.1978
# --
# Epoch 4/25
# -----
# Stage: train
# Loss: 1.6424 - Accuracy: 0.2155
# Stage: val
# Loss: 1.6301 - Accuracy: 0.2515
# --
# Epoch 5/25
# -----
# Stage: train
# Loss: 1.6362 - Accuracy: 0.2257
# Stage: val
# Loss: 1.7897 - Accuracy: 0.1937
# --
# Epoch 6/25
# -----
# Stage: train
# Loss: 1.6267 - Accuracy: 0.2246
# Stage: val
# Loss: 1.6762 - Accuracy: 0.2386
# --
# Epoch 7/25
# -----
# Stage: train
# Loss: 1.6265 - Accuracy: 0.2250
# Stage: val
# Loss: 1.5885 - Accuracy: 0.2166
# --
# Epoch 8/25
# -----
# Stage: train
# Loss: 1.6099 - Accuracy: 0.2394
# Stage: val
# Loss: 1.7385 - Accuracy: 0.2423
# --
# Epoch 9/25
# -----
# Stage: train
# Loss: 1.6129 - Accuracy: 0.2246
# Stage: val
# Loss: 1.6636 - Accuracy: 0.2386
# --
# Epoch 10/25
# -----
# Stage: train
# Loss: 1.6141 - Accuracy: 0.2254
# Stage: val
# Loss: 1.6469 - Accuracy: 0.2207
# --
# Epoch 11/25
# -----
# Stage: train
# Loss: 1.6248 - Accuracy: 0.2298
# Stage: val
# Loss: 1.6643 - Accuracy: 0.2263
# --
# Epoch 12/25
# -----
# Stage: train
# Loss: 1.6269 - Accuracy: 0.2239
# Stage: val
# Loss: 1.6195 - Accuracy: 0.2345
# --
# Epoch 13/25
# -----
# Stage: train
# Loss: 1.6238 - Accuracy: 0.2226
# Stage: val
# Loss: 1.6192 - Accuracy: 0.2244
# --
# Epoch 14/25
# -----
# Stage: train
# Loss: 1.6142 - Accuracy: 0.2317
# Stage: val
# Loss: 1.6191 - Accuracy: 0.2235
# --
# Epoch 15/25
# -----
# Stage: train
# Loss: 1.6132 - Accuracy: 0.2314
# Stage: val
# Loss: 1.7012 - Accuracy: 0.2106
# --
# Epoch 16/25
# -----
# Stage: train
# Loss: 1.6148 - Accuracy: 0.2246
# Stage: val
# Loss: 1.6176 - Accuracy: 0.2313
# --
# Epoch 17/25
# -----
# Stage: train
# Loss: 1.6119 - Accuracy: 0.2274
# Stage: val
# Loss: 1.6384 - Accuracy: 0.1992
# --
# Epoch 18/25
# -----
# Stage: train
# Loss: 1.6131 - Accuracy: 0.2302
# Stage: val
# Loss: 1.6546 - Accuracy: 0.2226
# --
# Epoch 19/25
# -----
# Stage: train
# Loss: 1.6096 - Accuracy: 0.2334
# Stage: val
# Loss: 1.6146 - Accuracy: 0.2354
# --
# Epoch 20/25
# -----
# Stage: train
# Loss: 1.5959 - Accuracy: 0.2443
# Stage: val
# Loss: 1.6609 - Accuracy: 0.2175
# --
# Epoch 21/25
# -----
# Stage: train
# Loss: 1.5951 - Accuracy: 0.2433
# Stage: val
# Loss: 1.5869 - Accuracy: 0.2308
# --
# Epoch 22/25
# -----
# Stage: train
# Loss: 1.5814 - Accuracy: 0.2544
# Stage: val
# Loss: 1.6972 - Accuracy: 0.2414
# --
# Epoch 23/25
# -----
# Stage: train
# Loss: 1.5695 - Accuracy: 0.2635
# Stage: val
# Loss: 1.6573 - Accuracy: 0.2478
# --
# Epoch 24/25
# -----
# Stage: train
# Loss: 1.5553 - Accuracy: 0.2745
# Stage: val
# Loss: 1.5911 - Accuracy: 0.2478
# --
# Epoch 25/25
# -----
# Stage: train
# Loss: 1.5434 - Accuracy: 0.2870
# Stage: val
# Loss: 1.5734 - Accuracy: 0.2864
# Best validation accuracy: 0.286370
#
# Fold 3
# --
# Epoch 1/25
# -----
# Stage: train
# Loss: 1.7359 - Accuracy: 0.2170
# Stage: val
# Loss: 1.7362 - Accuracy: 0.2240
# --
# Epoch 2/25
# -----
# Stage: train
# Loss: 1.6735 - Accuracy: 0.2158
# Stage: val
# Loss: 1.8184 - Accuracy: 0.2350
# --
# Epoch 3/25
# -----
# Stage: train
# Loss: 1.6624 - Accuracy: 0.2205
# Stage: val
# Loss: 1.6356 - Accuracy: 0.2263
# --
# Epoch 4/25
# -----
# Stage: train
# Loss: 1.6475 - Accuracy: 0.2226
# Stage: val
# Loss: 1.6109 - Accuracy: 0.2561
# --
# Epoch 5/25
# -----
# Stage: train
# Loss: 1.6318 - Accuracy: 0.2306
# Stage: val
# Loss: 1.6028 - Accuracy: 0.2345
# --
# Epoch 6/25
# -----
# Stage: train
# Loss: 1.6269 - Accuracy: 0.2327
# Stage: val
# Loss: 1.5945 - Accuracy: 0.2175
# --
# Epoch 7/25
# -----
# Stage: train
# Loss: 1.6191 - Accuracy: 0.2317
# Stage: val
# Loss: 1.5814 - Accuracy: 0.2556
# --
# Epoch 8/25
# -----
# Stage: train
# Loss: 1.6046 - Accuracy: 0.2420
# Stage: val
# Loss: 1.5929 - Accuracy: 0.2469
# --
# Epoch 9/25
# -----
# Stage: train
# Loss: 1.5997 - Accuracy: 0.2428
# Stage: val
# Loss: 1.6769 - Accuracy: 0.1941
# --
# Epoch 10/25
# -----
# Stage: train
# Loss: 1.5934 - Accuracy: 0.2519
# Stage: val
# Loss: 1.5910 - Accuracy: 0.2428
# --
# Epoch 11/25
# -----
# Stage: train
# Loss: 1.5838 - Accuracy: 0.2599
# Stage: val
# Loss: 1.5698 - Accuracy: 0.2579
# --
# Epoch 12/25
# -----
# Stage: train
# Loss: 1.5489 - Accuracy: 0.2760
# Stage: val
# Loss: 1.5571 - Accuracy: 0.3015
# --
# Epoch 13/25
# -----
# Stage: train
# Loss: 1.5434 - Accuracy: 0.2862
# Stage: val
# Loss: 1.5731 - Accuracy: 0.2891
# --
# Epoch 14/25
# -----
# Stage: train
# Loss: 1.5091 - Accuracy: 0.3096
# Stage: val
# Loss: 1.6318 - Accuracy: 0.3112
# --
# Epoch 15/25
# -----
# Stage: train
# Loss: 1.5173 - Accuracy: 0.3057
# Stage: val
# Loss: 1.5501 - Accuracy: 0.2877
# --
# Epoch 16/25
# -----
# Stage: train
# Loss: 1.5178 - Accuracy: 0.3075
# Stage: val
# Loss: 1.6670 - Accuracy: 0.2676
# --
# Epoch 17/25
# -----
# Stage: train
# Loss: 1.5472 - Accuracy: 0.2851
# Stage: val
# Loss: 1.5208 - Accuracy: 0.2910
# --
# Epoch 18/25
# -----
# Stage: train
# Loss: 1.5338 - Accuracy: 0.2976
# Stage: val
# Loss: 1.5627 - Accuracy: 0.3157
# --
# Epoch 19/25
# -----
# Stage: train
# Loss: 1.5314 - Accuracy: 0.2994
# Stage: val
# Loss: 1.6737 - Accuracy: 0.2877
# --
# Epoch 20/25
# -----
# Stage: train
# Loss: 1.5853 - Accuracy: 0.2517
# Stage: val
# Loss: 1.6350 - Accuracy: 0.2533
# --
# Epoch 21/25
# -----
# Stage: train
# Loss: 1.5957 - Accuracy: 0.2411
# Stage: val
# Loss: 1.5892 - Accuracy: 0.2382
# --
# Epoch 22/25
# -----
# Stage: train
# Loss: 1.5713 - Accuracy: 0.2617
# Stage: val
# Loss: 1.5795 - Accuracy: 0.2506
# --
# Epoch 23/25
# -----
# Stage: train
# Loss: 1.5562 - Accuracy: 0.2721
# Stage: val
# Loss: 1.5637 - Accuracy: 0.2882
# --
# Epoch 24/25
# -----
# Stage: train
# Loss: 1.5295 - Accuracy: 0.2964
# Stage: val
# Loss: 1.5199 - Accuracy: 0.3167
# --
# Epoch 25/25
# -----
# Stage: train
# Loss: 1.4592 - Accuracy: 0.3549
# Stage: val
# Loss: 1.5005 - Accuracy: 0.3327
# Best validation accuracy: 0.332721
#
# Fold 4
# --
# Epoch 1/25
# -----
# Stage: train
# Loss: 1.7728 - Accuracy: 0.2132
# Stage: val
# Loss: 1.7641 - Accuracy: 0.2163
# --
# Epoch 2/25
# -----
# Stage: train
# Loss: 1.6655 - Accuracy: 0.2307
# Stage: val
# Loss: 1.6226 - Accuracy: 0.2378
# --
# Epoch 3/25
# -----
# Stage: train
# Loss: 1.6506 - Accuracy: 0.2318
# Stage: val
# Loss: 1.6324 - Accuracy: 0.2360
# --
# Epoch 4/25
# -----
# Stage: train
# Loss: 1.6272 - Accuracy: 0.2338
# Stage: val
# Loss: 1.7385 - Accuracy: 0.2470
# --
# Epoch 5/25
# -----
# Stage: train
# Loss: 1.6217 - Accuracy: 0.2327
# Stage: val
# Loss: 1.6542 - Accuracy: 0.2213
# --
# Epoch 6/25
# -----
# Stage: train
# Loss: 1.6255 - Accuracy: 0.2316
# Stage: val
# Loss: 1.6115 - Accuracy: 0.2599
# --
# Epoch 7/25
# -----
# Stage: train
# Loss: 1.6188 - Accuracy: 0.2335
# Stage: val
# Loss: 1.6296 - Accuracy: 0.2401
# --
# Epoch 8/25
# -----
# Stage: train
# Loss: 1.6127 - Accuracy: 0.2357
# Stage: val
# Loss: 1.7162 - Accuracy: 0.2383
# --
# Epoch 9/25
# -----
# Stage: train
# Loss: 1.6147 - Accuracy: 0.2296
# Stage: val
# Loss: 1.6391 - Accuracy: 0.2268
# --
# Epoch 10/25
# -----
# Stage: train
# Loss: 1.6136 - Accuracy: 0.2297
# Stage: val
# Loss: 1.6639 - Accuracy: 0.2342
# --
# Epoch 11/25
# -----
# Stage: train
# Loss: 1.6003 - Accuracy: 0.2352
# Stage: val
# Loss: 1.6594 - Accuracy: 0.2429
# --
# Epoch 12/25
# -----
# Stage: train
# Loss: 1.5941 - Accuracy: 0.2479
# Stage: val
# Loss: 1.6438 - Accuracy: 0.2415
# --
# Epoch 13/25
# -----
# Stage: train
# Loss: 1.5939 - Accuracy: 0.2385
# Stage: val
# Loss: 1.6511 - Accuracy: 0.2466
# --
# Epoch 14/25
# -----
# Stage: train
# Loss: 1.6137 - Accuracy: 0.2300
# Stage: val
# Loss: 1.7501 - Accuracy: 0.2507
# --
# Epoch 15/25
# -----
# Stage: train
# Loss: 1.6070 - Accuracy: 0.2297
# Stage: val
# Loss: 1.6167 - Accuracy: 0.2484
# --
# Epoch 16/25
# -----
# Stage: train
# Loss: 1.6107 - Accuracy: 0.2288
# Stage: val
# Loss: 1.7503 - Accuracy: 0.2204
# --
# Epoch 17/25
# -----
# Stage: train
# Loss: 1.5990 - Accuracy: 0.2261
# Stage: val
# Loss: 1.6255 - Accuracy: 0.2438
# --
# Epoch 18/25
# -----
# Stage: train
# Loss: 1.5867 - Accuracy: 0.2411
# Stage: val
# Loss: 1.6309 - Accuracy: 0.2355
# --
# Epoch 19/25
# -----
# Stage: train
# Loss: 1.5884 - Accuracy: 0.2351
# Stage: val
# Loss: 1.6481 - Accuracy: 0.2433
# --
# Epoch 20/25
# -----
# Stage: train
# Loss: 1.5849 - Accuracy: 0.2321
# Stage: val
# Loss: 1.6331 - Accuracy: 0.2484
# --
# Epoch 21/25
# -----
# Stage: train
# Loss: 1.5708 - Accuracy: 0.2430
# Stage: val
# Loss: 1.6626 - Accuracy: 0.2548
# --
# Epoch 22/25
# -----
# Stage: train
# Loss: 1.5675 - Accuracy: 0.2520
# Stage: val
# Loss: 1.7104 - Accuracy: 0.2608
# --
# Epoch 23/25
# -----
# Stage: train
# Loss: 1.6009 - Accuracy: 0.2266
# Stage: val
# Loss: 1.6167 - Accuracy: 0.1905
# --
# Epoch 24/25
# -----
# Stage: train
# Loss: 1.5793 - Accuracy: 0.2423
# Stage: val
# Loss: 1.5902 - Accuracy: 0.2470
# --
# Epoch 25/25
# -----
# Stage: train
# Loss: 1.5681 - Accuracy: 0.2530
# Stage: val
# Loss: 1.5607 - Accuracy: 0.2796
# Best validation accuracy: 0.279614
#
# Training complete in 475m 16s
# Mean acc: 0.3601908778637053

# %%
import sys
sys.path.append('Scripts')
sys.path.append('C:\\Users\\Patrick\\Documents\\GitHub\\BCI_ssvep_dataset')
import os

from utils import path
from dsloader import *
import pandas as pd
import numpy as np

# %%
split = {
    '256':1,
    '512':2,
    '768':3
}
s = 768

RawDataPath = path("C:\\Users\\Patrick\\Documents\\GitHub\\BCI_ssvep_dataset\\dataset")
DataPath = path('C:\\Users\\Patrick\\Documents\\GitHub\\ICDeepLearning\\Data\\Originais\\'+str(s))

Subjects = set()
Stages = ['1', '2', '3', '4', '5']
for filename in os.listdir(RawDataPath()):
    Subjects.add(filename[6:20])
    
for subjectName in Subjects:
    os.mkdir(DataPath/subjectName)
    for i in Stages:
        os.mkdir(DataPath/subjectName+"//"+i)
        
for file in RawDataFiles:
    filename = file[6:20]
    stage = file[-5]
    outputPath = DataPath()+"\\"+filename+"\\"+stage
    
    data = get_data_from_file(RawDataPath()+'\\'+file)
    splittedData = get_splitted_dataset(data[0], split[str(s)])
    k = len(splittedData)
    
    for i, data in zip(range(1, k), splittedData[:-1]):
        data.to_csv(outputPath+"\\"+str(i)+".csv", sep = ',', header = False, index = False)
        
    if len(splittedData[-1]) == s:
        splittedData[-1].to_csv(outputPath+"\\"+str(i + 1)+".csv", header = False, index=  False)
# Out:
# Directory C:\Users\Patrick\Documents\GitHub\BCI_ssvep_dataset\dataset loaded successfully.
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\Originais\768 loaded successfully.

# %%
split = {
    '256':1,
    '512':2,
    '768':3
}
s = str(256)
cols = ['Cz', 'Oz']

dataset1 = get_dataset(path='C:\\Users\\Patrick\\Documents\\GitHub\\BCI_ssvep_dataset\\dataset', cols = cols, export_to_file=False, filename='cz-oz.txt', n_seconds_split = split[s])
# temp = pd.DataFrame(columns = ['subject', 'state', 'path'])

# for state in [1, 2, 3, 4, 5]:
#     df = dataset1[dataset1['class'] == state].reset_index()
#     path = 'C:\\Users\\Patrick\\Documents\\GitHub\\ICDeepLearning\\Data\\FullDataset\\'+s+'\\_\\'+str(state)
    
#     for i in range(len(df)):
#         series = df.loc[i][:-1].values
#         filePath = path+'\\'+str(i)+'.csv'
        
#         tempRow = pd.DataFrame([['_', str(state), filePath]], columns = ['subject', 'state', 'path'])
#         temp = temp.append(tempRow)
#         np.savetxt(filePath, series)
        
# temp.to_csv('SSVEPDatasetFullDataset_'+s+'.csv', index = False)

# %%
dataset1
# Out:
#                  0             1         2         3             4         5  \
# 0    -4.494965e-05 -4.599640e-05  0.000004 -0.000005  5.513176e-05  0.000056
# 1    -6.588272e-06  2.470175e-07 -0.000004  0.000006 -1.499699e-05 -0.000012
# 2    -6.588272e-06  2.470175e-07 -0.000004  0.000006 -1.499699e-05 -0.000012
# 3    -7.613961e-05 -8.447460e-05 -0.000075 -0.000077 -5.183769e-05 -0.000049
# 4    -7.613961e-05 -8.447460e-05 -0.000075 -0.000077 -5.183769e-05 -0.000049
# ...            ...           ...       ...       ...           ...       ...
# 4681 -1.861917e-06 -2.172428e-06 -0.000002 -0.000005 -2.735326e-07 -0.000004
# 4682 -1.861917e-06 -2.172428e-06 -0.000002 -0.000005 -2.735326e-07 -0.000004
# 4683 -4.794285e-06 -1.084057e-05 -0.000004 -0.000009 -2.617213e-06 -0.000008
# 4684 -4.794285e-06 -1.084057e-05 -0.000004 -0.000009 -2.617213e-06 -0.000008
# 4685 -1.245016e-07  1.066750e-05  0.000001  0.000009  3.851806e-06  0.000001
#
#              6         7             8         9  ...           503       504  \
# 0     0.000060  0.000072  2.816364e-05  0.000040  ...  5.844892e-06  0.000010
# 1    -0.000034 -0.000033 -3.597854e-05 -0.000032  ...  1.092971e-04  0.000124
# 2    -0.000034 -0.000033 -3.597854e-05 -0.000032  ...  1.092971e-04  0.000124
# 3    -0.000019 -0.000012 -6.136906e-06  0.000005  ... -1.122666e-05 -0.000065
# 4    -0.000019 -0.000012 -6.136906e-06  0.000005  ... -1.122666e-05 -0.000065
# ...        ...       ...           ...       ...  ...           ...       ...
# 4681  0.000001  0.000002  6.179897e-07  0.000005  ... -1.956493e-06  0.000006
# 4682  0.000001  0.000002  6.179897e-07  0.000005  ... -1.956493e-06  0.000006
# 4683 -0.000004 -0.000007 -7.114740e-06 -0.000005  ...  1.370913e-05 -0.000002
# 4684 -0.000004 -0.000007 -7.114740e-06 -0.000005  ...  1.370913e-05 -0.000002
# 4685  0.000004 -0.000007  1.727603e-06 -0.000013  ... -6.118264e-07  0.000003
#
#                505       506           507       508       509           510  \
# 0     1.004585e-05  0.000013  1.480705e-05  0.000002  0.000002 -7.816675e-06
# 1     8.936505e-05  0.000048  5.384931e-06 -0.000031 -0.000067 -6.627265e-05
# 2     8.936505e-05  0.000048  5.384931e-06 -0.000031 -0.000067 -6.627265e-05
# 3    -2.577276e-05 -0.000057 -3.827106e-05 -0.000034 -0.000041 -2.897167e-05
# 4    -2.577276e-05 -0.000057 -3.827106e-05 -0.000034 -0.000041 -2.897167e-05
# ...            ...       ...           ...       ...       ...           ...
# 4681 -4.301433e-06  0.000003 -9.283282e-06 -0.000001 -0.000014 -4.136256e-06
# 4682 -4.301433e-06  0.000003 -9.283282e-06 -0.000001 -0.000014 -4.136256e-06
# 4683  1.195359e-05 -0.000003  8.465389e-06 -0.000003  0.000007 -8.793510e-07
# 4684  1.195359e-05 -0.000003  8.465389e-06 -0.000003  0.000007 -8.793510e-07
# 4685 -8.432380e-07  0.000005  4.997128e-07  0.000006  0.000002  6.362496e-06
#
#            511  class
# 0    -0.000008    1.0
# 1    -0.000086    1.0
# 2    -0.000086    1.0
# 3    -0.000043    1.0
# 4    -0.000043    1.0
# ...        ...    ...
# 4681 -0.000014    5.0
# 4682 -0.000014    5.0
# 4683  0.000008    5.0
# 4684  0.000008    5.0
# 4685  0.000006    5.0
#
# [4686 rows x 513 columns]

# %%
import sys
sys.path.append('C:\\Users\\Patrick\\Documents\\GitHub\\ICDeepLearning\\Scripts')
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, utils, datasets, models
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np

from utils import path
from DataVis import createInputFigure
from NNUtils import *
from NNCreationAux import *

from sklearn import preprocessing
import os
import time
import copy

# %% [markdown]
# ***

# %%
modelType = 'dense'
modelSize = '161'
data_type = '512'
figSize = '128'
folder = 'GAF_Combinados_difference'

model_name = modelType+modelSize

# %%
dataloader, dataloaders, dataset_sizes, class_names = getData(data_type, folder)

# %%
model = model_selection(modelName, numClasses)
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr = 0.001, momentum = 0.4)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 10, gamma = 0.1)
model, stats = train(model, dataloaders, dataset_sizes, criterion, optimizer, scheduler, num_epochs = 2)

# %% [markdown]
# ***

# %%
data_type = '1024'
folder = 'RP_Combinados'
path = 'C:\\Users\\Patrick\\Documents\\GitHub\\ICDeepLearning\\Data\\Imagens\\'+folder+'\\'+data_type
dataset = get_dataset(path, 224)
dataloader, dataloaders, dataset_sizes, class_names = getData(data_type, folder, batch_size = 64)

# %%
dataset_sizes
# Out:
# {'train': 1082, 'test': 270}

# %%
model = model_selection('resnet152', 5).to(device)
optimizer = optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)
criterion = nn.CrossEntropyLoss()
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 7, gamma = 0.1)

# %%
model, _, _ = kfold_train(model, dataset, criterion, optimizer, num_epochs = 20, num_folds = 5)
# Out:
# Fold 0
# --
# Epoch 1/20
# -----
# Stage: train
# Loss: 1.8383 - Accuracy: 0.2211
# Stage: test
# Loss: 2.0515 - Accuracy: 0.2694
# --
# Epoch 2/20
# -----
# Stage: train
# Loss: 1.6883 - Accuracy: 0.2377
# Stage: test
# Loss: 1.8475 - Accuracy: 0.2288
# --
# Epoch 3/20
# -----
# Stage: train
# Loss: 1.6552 - Accuracy: 0.2396
# Stage: test
# Loss: 1.9426 - Accuracy: 0.2288
# --
# Epoch 4/20
# -----
# Stage: train
# Loss: 1.5921 - Accuracy: 0.2923
# Stage: test
# Loss: 1.9024 - Accuracy: 0.2583
# --
# Epoch 5/20
# -----
# Stage: train
# Loss: 1.4245 - Accuracy: 0.3978
# Stage: test
# Loss: 1.7455 - Accuracy: 0.2915
# --
# Epoch 6/20
# -----
# Stage: train
# Loss: 1.3737 - Accuracy: 0.4440
# Stage: test
# Loss: 2.1209 - Accuracy: 0.2694
# --
# Epoch 7/20
# -----
# Stage: train
# Loss: 1.2181 - Accuracy: 0.5162
# Stage: test
# Loss: 1.7750 - Accuracy: 0.3137
# --
# Epoch 8/20
# -----
# Stage: train
# Loss: 1.0184 - Accuracy: 0.6087
# Stage: test
# Loss: 1.9268 - Accuracy: 0.3247
# --
# Epoch 9/20
# -----
# Stage: train
# Loss: 0.8498 - Accuracy: 0.6892
# Stage: test
# Loss: 2.0244 - Accuracy: 0.3469
# --
# Epoch 10/20
# -----
# Stage: train
# Loss: 0.6700 - Accuracy: 0.7512
# Stage: test
# Loss: 2.6046 - Accuracy: 0.3506
# --
# Epoch 11/20
# -----
# Stage: train
# Loss: 0.6208 - Accuracy: 0.7771
# Stage: test
# Loss: 2.4127 - Accuracy: 0.3284
# --
# Epoch 12/20
# -----
# Stage: train
# Loss: 0.4925 - Accuracy: 0.8205
# Stage: test
# Loss: 2.2263 - Accuracy: 0.4133
# --
# Epoch 13/20
# -----
# Stage: train
# Loss: 0.4382 - Accuracy: 0.8501
# Stage: test
# Loss: 2.3474 - Accuracy: 0.4244
# --
# Epoch 14/20
# -----
# Stage: train
# Loss: 0.3882 - Accuracy: 0.8696
# Stage: test
# Loss: 2.2195 - Accuracy: 0.4280
# --
# Epoch 15/20
# -----
# Stage: train
# Loss: 0.3553 - Accuracy: 0.8686
# Stage: test
# Loss: 2.3283 - Accuracy: 0.4317
# --
# Epoch 16/20
# -----
# Stage: train
# Loss: 0.2968 - Accuracy: 0.8964
# Stage: test
# Loss: 2.6750 - Accuracy: 0.4096
# --
# Epoch 17/20
# -----
# Stage: train
# Loss: 0.2430 - Accuracy: 0.9112
# Stage: test
# Loss: 2.6073 - Accuracy: 0.4391
# --
# Epoch 18/20
# -----
# Stage: train
# Loss: 0.2566 - Accuracy: 0.9158
# Stage: test
# Loss: 2.2592 - Accuracy: 0.3838
# --
# Epoch 19/20
# -----
# Stage: train
# Loss: 0
# --
# Epoch 2/20
# -----
# Stage: train
# Loss: 1.6752 - Accuracy: 0.2375
# Stage: test
# Loss: 1.7000 - Accuracy: 0.2074
# --
# Epoch 3/20
# -----
# Stage: train
# Loss: 1.6193 - Accuracy: 0.2874
# Stage: test
# Loss: 1.5823 - Accuracy: 0.2926
# --
# Epoch 4/20
# -----
# Stage: train
# Loss: 1.5054 - Accuracy: 0.3604
# Stage: test
# Loss: 1.6016 - Accuracy: 0.2889
# --
# Epoch 5/20
# -----
# Stage: train
# Loss: 1.3904 - Accuracy: 0.4261
# Stage: test
# Loss: 1.7128 - Accuracy: 0.2852
# --
# Epoch 6/20
# -----
# Stage: train
# Loss: 1.1683 - Accuracy: 0.5370
# Stage: test
# Loss: 1.6943 - Accuracy: 0.3630
# --
# Epoch 7/20
# -----
# Stage: train
# Loss: 1.0285 - Accuracy: 0.6137
# Stage: test
# Loss: 1.6470 - Accuracy: 0.3556
# --
# Epoch 8/20
# -----
# Stage: train
# Loss: 0.8595 - Accuracy: 0.6848
# Stage: test
# Loss: 2.1693 - Accuracy: 0.4296
# --
# Epoch 9/20
# -----
# Stage: train
# Loss: 0.6891 - Accuracy: 0.7551
# Stage: test
# Loss: 2.2306 - Accuracy: 0.4333
# --
# Epoch 10/20
# -----
# Stage: train
# Loss: 0.5390 - Accuracy: 0.8152
# Stage: test
# Loss: 1.9170 - Accuracy: 0.4630
# --
# Epoch 11/20
# -----
# Stage: train
# Loss: 0.4668 - Accuracy: 0.8364
# Stage: test
# Loss: 2.3344 - Accuracy: 0.4148
# --
# Epoch 12/20
# -----
# Stage: train
# Loss: 0.4171 - Accuracy: 0.8429
# Stage: test
# Loss: 1.8689 - Accuracy: 0.4259
# --
# Epoch 13/20
# -----
# Stage: train
# Loss: 0.3275 - Accuracy: 0.8808
# Stage: test
# Loss: 2.2128 - Accuracy: 0.4667
# --
# Epoch 14/20
# -----
# Stage: train
# Loss: 0.2805 - Accuracy: 0.9104
# Stage: test
# Loss: 1.8601 - Accuracy: 0.4778
# --
# Epoch 15/20
# -----
# Stage: train
# Loss: 0.2139 - Accuracy: 0.9261
# Stage: test
# Loss: 2.0522 - Accuracy: 0.4556
# --
# Epoch 16/20
# -----
# Stage: train
# Loss: 0.2820 - Accuracy: 0.9011
# Stage: test
# Loss: 1.7847 - Accuracy: 0.4741
# --
# Epoch 17/20
# -----
# Stage: train
# Loss: 0.1939 - Accuracy: 0.9372
# Stage: test
# Loss: 2.1151 - Accuracy: 0.4519
# --
# Epoch 18/20
# -----
# Stage: train
# Loss: 0.1580 - Accuracy: 0.9427
# Stage: test
# Loss: 2.0478 - Accuracy: 0.5370
# --
# Epoch 19/20
# -----
# Stage: train
# Loss: 0.1260 - Accuracy: 0.9649
# Stage: test
# Loss: 2.0292 - Accuracy: 0.5000
# --
# Epoch 20/20
# -----
# Stage: train
# Loss: 0.1194 - Accuracy: 0.9584
# Stage: test
# Loss: 1.7082 - Accuracy: 0.5037
# Best validation accuracy: 0.537037
#
# Training complete in 354m 20s
# Mean acc: 0.49483941506081724

# %% [markdown]
# ***

# %%
batch_size = 1
image_size = 224
folder = 'Test_GASF'
figPath = 'C:\\Users\\Patrick\\Documents\\GitHub\\ICDeepLearning\\Data\\'+folder+'\\512'
dataloader, dataloaders, dataset_sizes, class_names = getData(data_type, folder, batch_size = 1)

# %%
class predictor(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model
        
    def predict(self, dataloader):
        outputs = []
        targets = []
        for sample, target in dataloader:
            sample = sample.to(device)
            target = target.to(device)
            o = torch.argmax(F.softmax(self.model(sample), dim = 1)).item()
            outputs.append(o)
            targets.append(target.item())
            
        outputs = np.array(outputs)
        targets = np.array(targets)
        right_pred = 1*(outputs == targets)
        return outputs, right_pred

# %%
predic = predictor(res18)
_, outres18 = predic.predict(dataloader)

# %%
predic = predictor(res34)
_, outres34 = predic.predict(dataloader)

# %%
predic = predictor(model)
_, outmodel = predic.predict(dataloader)

# %%
np.count_nonzero(outmodel)/500
# Out:
# 0.188

# %%
np.count_nonzero(outres18)/500
# Out:
# 0.178

# %%
np.count_nonzero(outres34)/500
# Out:
# 0.202

# %%
from scipy import stats
stats.ttest_ind(outres18, outres34, equal_var=True)
# Out:
# Ttest_indResult(statistic=-0.9667862845385763, pvalue=0.33388509993212834)

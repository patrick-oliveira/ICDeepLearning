# %%
import sys
sys.path.append('Scripts')

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, utils, datasets, models
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np

from utils import path
from utils import createInputFigure

from sklearn import preprocessing
import os
import time
import copy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-5765ef4c1ec5> in <module>
#       2 sys.path.append('Scripts')
#       3
# ----> 4 import torch
#       5 import torch.nn as nn
#       6 import torch.optim as optim
#
# ~\Anaconda3\lib\site-packages\torch\__init__.py in <module>
#      79 del _dl_flags
#      80
# ---> 81 from torch._C import *
#      82
#      83 __all__ += [name for name in dir(_C)
#
# ImportError: DLL load failed: The paging file is too small for this operation to complete.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
image_size = 224
batch_size = 16
workers = 2
ngpu = 1
validation_split = .2
train_split = 0
shuffle_dataset = True
random_seed = 42
    
def getData(dataType):
    figPath = path('C:\\Users\\Patrick\\Documents\\GitHub\\ICDeepLearning\\Data\\GAF_Combinados\\'+dataType)

    dataset = datasets.ImageFolder(root = figPath(),
                                  transform = transforms.Compose([
                                      transforms.Resize(image_size),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5),
                                                           (0.5, 0.5, 0.5))
                                  ]))

    class_names = dataset.classes

    dataset_size = len(dataset)
    indices = list(range(dataset_size))
    trainsplit = int(np.floor(train_split * dataset_size))
    if shuffle_dataset:
        np.random.seed(random_seed)
        np.random.shuffle(indices)
    train_indices, test_indices = indices[trainsplit:], indices[:trainsplit]
    trainset_size = len(train_indices)
    valsplit = int(np.floor(validation_split * trainset_size))
    train_indices, val_indices = train_indices[valsplit:], train_indices[:valsplit]

    train_sampler = SubsetRandomSampler(train_indices)
    valid_sampler = SubsetRandomSampler(val_indices)
    test_sampler = SubsetRandomSampler(train_indices)

    train_loader = DataLoader(dataset, batch_size = batch_size,
                                        sampler = train_sampler)
    validation_loader = DataLoader(dataset, batch_size = batch_size,
                                        sampler = valid_sampler)
    test_loader = DataLoader(dataset, batch_size = batch_size,
                                        sampler = test_sampler)


    dataloaders = {"train": train_loader, "val": validation_loader, "test": test_loader}

    dataset_sizes = {"train": len(train_indices),
                     "val": len(val_indices),
                     "test": len(test_indices)}
    dataloader = torch.utils.data.DataLoader(dataset, batch_size = batch_size,
                                             shuffle = True, num_workers = workers)

    
    return dataloaders, dataset_sizes, dataloader, class_names

def train_model(model, criterion, optimizer, scheduler, dataloaders, dataset_sizes, dataloader, num_epochs = 25):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    trainAcc = []
    trainLoss = []
    validAcc = []
    validLoss = []
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train() # Set model to training mode
            else:
                model.eval()  # Set model to evaluate mode
            
            running_loss = 0.0
            running_corrects = 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                # zero the parameter gradients
                optimizer.zero_grad()
                
                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        
                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()
                
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            if phase == 'train':
                trainAcc.append(epoch_acc)
                trainLoss.append(epoch_loss)
            else:
                validAcc.append(epoch_acc)
                validLoss.append(epoch_loss)
                
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))
            
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                
        print()
        
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format( time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
    
    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, [trainAcc, trainLoss], [validAcc, validLoss]


def visualize_model(model, num_images = 6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()
    
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            
            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])
                
                if images_so_far == num_images:
                    model.train(mode = was_training)
                    return
        model.train(mode = was_training)
        
        
def trainModel(model, modelName, criterion, optimizer, scheduler):
#     dataTypes = ['512', '768', 'shifted']
    dataTypes = ['512']
    stats = {
        '512': [],
        '768': [],
        'shifted': []
    }
    for t in dataTypes:
        print("Training stage:{}".format(t))
        dataloaders, dataset_sizes, dataloader, _ = getData(t)
        model, *stats[t] = train_model(model, criterion, optimizer, scheduler, dataloaders, dataset_sizes, dataloader, num_epochs = 15)
#         torch.save(model.state_dict(), 'Models\\'+modelName+'\\'+t+".pth")
#         torch.save(stats, 'Models\\'+modelName+'\\stats'+t+'.pth')
        
    return model, stats

device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
dataloaders, dataset_sizes, dataloader, class_names = getData('512')
# device = "cpu"
real_batch = next(iter(dataloader))
plt.figure(figsize = (25, 25))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device), padding = 2, normalize = True).cpu(),
                        (1, 2, 0)))

criterion = nn.CrossEntropyLoss()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-67f78ebd7b99> in <module>
#     176     return model, stats
#     177
# --> 178 device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
#     179 dataloaders, dataset_sizes, dataloader, class_names = getData('512')
#     180 # device = "cpu"
#
# NameError: name 'torch' is not defined

# %%
def imshow(inp, title = None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    inp = std*inp + mean
    inp = np.clip(inp, 0, 1)
    plt.figure(figsize = (25, 25))
    plt.axis("off")
    plt.title("Training Images")
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated
    
# Get a batch of training data
inputs, classes = next(iter(train_loader))

# Make a grid from a batch
out = utils.make_grid(inputs)

imshow(out, title = [class_names[x] for x in classes])

# %%
model_ft = models.resnet50(pretrained = True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalize to nn.Linear(num_ftrs, len(class_names))
numClasses = 5
model_ft.fc = nn.Linear(num_ftrs, numClasses)

model_ft = model_ft.to(device)

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum = 0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = optim.lr_scheduler.StepLR(optimizer_ft, step_size = 7, gamma = 0.1)

# %%
dataTypes = ['512', '768', 'shifted']
stats = {
    '512': [],
    '768': [],
    'shifted': []
}
for t in dataTypes:
    print("Training stage:{}".format(t))
    dataloaders, dataset_sizes, dataloader, _ = getData(t)
    model_ft, *stats[t] = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, dataloaders, dataset_sizes, dataloader, num_epochs = 10)
    torch.save(model_ft.state_dict(), 'Models\\'+t+".pth")
    torch.save(stats, 'Models\\resnet50\\stats'+t+'.pth')
    
del(model_ft)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/9
# ----------
# train Loss: 1.8932 Acc: 0.1998
# val Loss: 2.0706 Acc: 0.2596
#
# Epoch 1/9
# ----------
# train Loss: 1.7705 Acc: 0.2476
# val Loss: 2.1963 Acc: 0.1683
#
# Epoch 2/9
# ----------
# train Loss: 1.6706 Acc: 0.2835
# val Loss: 1.6713 Acc: 0.3173
#
# Epoch 3/9
# ----------
# train Loss: 1.4597 Acc: 0.3911
# val Loss: 1.7004 Acc: 0.3269
#
# Epoch 4/9
# ----------
# train Loss: 1.2667 Acc: 0.4713
# val Loss: 1.9899 Acc: 0.3413
#
# Epoch 5/9
# ----------
# train Loss: 1.1543 Acc: 0.5431
# val Loss: 2.1050 Acc: 0.3462
#
# Epoch 6/9
# ----------
# train Loss: 1.0272 Acc: 0.6053
# val Loss: 1.9618 Acc: 0.4135
#
# Epoch 7/9
# ----------
# train Loss: 0.5248 Acc: 0.8289
# val Loss: 1.9717 Acc: 0.4135
#
# Epoch 8/9
# ----------
# train Loss: 0.4300 Acc: 0.8624
# val Loss: 2.0874 Acc: 0.3894
#
# Epoch 9/9
# ----------
# train Loss: 0.2959 Acc: 0.9139
# ...

# %%
model_2 = models.resnet18(pretrained = True)
num_ftrs = model_2.fc.in_features
numClasses = 5
model_2.fc = nn.Linear(num_ftrs, numClasses)
model_2 = model_2.to(device)
optimizer_2 = optim.SGD(model_2.parameters(), lr = 0.001, momentum = 0.9)
exp_2_scheduler = optim.lr_scheduler.StepLR(optimizer_2, step_size = 7, gamma = 0.1)

model_2, statsResnet18 = trainModel(model_2, 'resnet18', criterion, optimizer_2, exp_2_scheduler)
del(model_2)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.8956 Acc: 0.2285
# val Loss: 1.8978 Acc: 0.2644
#
# Epoch 1/14
# ----------
# train Loss: 1.7943 Acc: 0.2907
# val Loss: 1.9022 Acc: 0.2548
#
# Epoch 2/14
# ----------
# train Loss: 1.7063 Acc: 0.3469
# val Loss: 2.2821 Acc: 0.2500
#
# Epoch 3/14
# ----------
# train Loss: 1.4536 Acc: 0.4522
# val Loss: 1.9166 Acc: 0.3317
#
# Epoch 4/14
# ----------
# train Loss: 1.1030 Acc: 0.5801
# val Loss: 2.2848 Acc: 0.3510
#
# Epoch 5/14
# ----------
# train Loss: 1.1053 Acc: 0.5969
# val Loss: 2.1435 Acc: 0.3942
#
# Epoch 6/14
# ----------
# train Loss: 0.9683 Acc: 0.6483
# val Loss: 2.3764 Acc: 0.3750
#
# Epoch 7/14
# ----------
# train Loss: 0.5659 Acc: 0.8014
# val Loss: 1.9537 Acc: 0.3990
#
# Epoch 8/14
# ----------
# train Loss: 0.3968 Acc: 0.8660
# val Loss: 2.0348 Acc: 0.4375
#
# Epoch 9/14
# ----------
# ...

# %%
model_3 = models.resnet34(pretrained = True)
num_ftrs = model_3.fc.in_features
numClasses = 5
model_3.fc = nn.Linear(num_ftrs, numClasses)
model_3 = model_3.to(device)
optimizer_3 = optim.SGD(model_3.parameters(), lr = 0.001, momentum = 0.9)
exp_3_scheduler = optim.lr_scheduler.StepLR(optimizer_3, step_size = 7, gamma = 0.1)

model_3, statsResnet34 = trainModel(model_3, 'resnet34', criterion, optimizer_3, exp_3_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.6565 Acc: 0.2548
# val Loss: 1.6700 Acc: 0.2644
#
# Epoch 1/14
# ----------
# train Loss: 1.2645 Acc: 0.5144
# val Loss: 1.5901 Acc: 0.3558
#
# Epoch 2/14
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1a6f4703a5c3> in <module>
#       7 exp_3_scheduler = optim.lr_scheduler.StepLR(optimizer_3, step_size = 7, gamma = 0.1)
#       8
# ----> 9 model_3, statsResnet34 = trainModel(model_3, 'resnet34', criterion, optimizer_3, exp_3_scheduler)
#
# <ipython-input-3-f62f09c55ed4> in trainModel(model, modelName, criterion, optimizer, scheduler)
#     170         print("Training stage:{}".format(t))
#     171         dataloaders, dataset_sizes, dataloader, _ = getData(t)
# ...

# %%
model_4 = models.resnet101(pretrained = True)
num_ftrs = model_4.fc.in_features
numClasses = 5
model_4.fc = nn.Linear(num_ftrs, numClasses)
model_4 = model_4.to(device)
optimizer_4 = optim.SGD(model_4.parameters(), lr = 0.001, momentum = 0.9)
exp_4_scheduler = optim.lr_scheduler.StepLR(optimizer_4, step_size = 7, gamma = 0.1)

model_4, statsResnet101 = trainModel(model_4, 'resnet101', criterion, optimizer_4, exp_4_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.8379 Acc: 0.2022
# val Loss: 1.9018 Acc: 0.2260
#
# Epoch 1/14
# ----------
# train Loss: 1.8279 Acc: 0.2560
# val Loss: 2.0004 Acc: 0.2308
#
# Epoch 2/14
# ----------
# train Loss: 1.7006 Acc: 0.2811
# val Loss: 2.3729 Acc: 0.1971
#
# Epoch 3/14
# ----------
# train Loss: 1.5941 Acc: 0.3864
# val Loss: 1.8766 Acc: 0.3077
#
# Epoch 4/14
# ----------
# train Loss: 1.4331 Acc: 0.4450
# val Loss: 2.2501 Acc: 0.2885
#
# Epoch 5/14
# ----------
# train Loss: 1.2407 Acc: 0.5239
# val Loss: 1.9745 Acc: 0.2933
#
# Epoch 6/14
# ----------
# train Loss: 1.0594 Acc: 0.6077
# val Loss: 2.9906 Acc: 0.3125
#
# Epoch 7/14
# ----------
# train Loss: 0.6993 Acc: 0.7560
# val Loss: 2.0411 Acc: 0.3462
#
# Epoch 8/14
# ----------
# train Loss: 0.4182 Acc: 0.8493
# val Loss: 2.0737 Acc: 0.4087
#
# Epoch 9/14
# ----------
# ...

# %%
model_5 = models.resnet152(pretrained = True)
num_ftrs = model_5.fc.in_features
numClasses = 5
model_5.fc = nn.Linear(num_ftrs, numClasses)
model_5 = model_5.to(device)
optimizer_5 = optim.SGD(model_5.parameters(), lr = 0.001, momentum = 0.9)
exp_5_scheduler = optim.lr_scheduler.StepLR(optimizer_5, step_size = 7, gamma = 0.1)

model_5, statsResnet101 = trainModel(model_5, 'resnet152', criterion, optimizer_5, exp_5_scheduler)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to C:\Users\Patrick/.cache\torch\checkpoints\resnet152-b121ed2d.pth
# 100%|████████████████████████████████████████████████████████████████████████████████| 230M/230M [04:37<00:00, 872kB/s]
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.8293 Acc: 0.2117
# val Loss: 1.9190 Acc: 0.2067
#
# Epoch 1/14
# ----------
# train Loss: 1.8106 Acc: 0.2285
# val Loss: 2.0199 Acc: 0.2596
#
# Epoch 2/14
# ----------
# train Loss: 1.6573 Acc: 0.2907
# val Loss: 1.8036 Acc: 0.2500
#
# Epoch 3/14
# ----------
# train Loss: 1.5254 Acc: 0.3732
# val Loss: 1.7054 Acc: 0.2885
#
# Epoch 4/14
# ----------
# train Loss: 1.3523 Acc: 0.4557
# val Loss: 1.7561 Acc: 0.3077
#
# Epoch 5/14
# ----------
# train Loss: 1.1661 Acc: 0.5478
# val Loss: 1.8051 Acc: 0.3894
#
# Epoch 6/14
# ----------
# train Loss: 1.1638 Acc: 0.5658
# ...

# %%
model_6 = models.densenet121(pretrained = True)
numClasses = 5
model_6.classifier = nn.Linear(1024, numClasses)
model_6 = model_6.to(device)
optimizer_6 = optim.SGD(model_6.parameters(), lr = 0.001, momentum = 0.9)
exp_6_scheduler = optim.lr_scheduler.StepLR(optimizer_6, step_size = 7, gamma = 0.1)
model_6, statsDensenet = trainModel(model_6, 'densenet121', criterion, optimizer_5, exp_6_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.7990 Acc: 0.2045
# val Loss: 1.8170 Acc: 0.2115
#
# Epoch 1/14
# ----------
# train Loss: 1.7826 Acc: 0.2057
# val Loss: 1.8489 Acc: 0.1923
#
# Epoch 2/14
# ----------
# train Loss: 1.7932 Acc: 0.2213
# val Loss: 1.8485 Acc: 0.2115
#
# Epoch 3/14
# ----------
# train Loss: 1.7897 Acc: 0.2045
# val Loss: 1.8342 Acc: 0.2212
#
# Epoch 4/14
# ----------
# train Loss: 1.7921 Acc: 0.2057
# val Loss: 1.8196 Acc: 0.2163
#
# Epoch 5/14
# ----------
# train Loss: 1.7812 Acc: 0.2117
# val Loss: 1.8475 Acc: 0.2212
#
# Epoch 6/14
# ----------
# train Loss: 1.7846 Acc: 0.2057
# val Loss: 1.8339 Acc: 0.2163
#
# Epoch 7/14
# ----------
# train Loss: 1.7905 Acc: 0.2045
# val Loss: 1.8440 Acc: 0.2019
#
# Epoch 8/14
# ----------
# train Loss: 1.7893 Acc: 0.2022
# val Loss: 1.8340 Acc: 0.2212
#
# Epoch 9/14
# ----------
# ...

# %%
model_7 = models.densenet161(pretrained = True)
numClasses = 5
model_7.classifier = nn.Linear(2208, numClasses)
model_7 = model_7.to(device)
optimizer_7 = optim.SGD(model_7.parameters(), lr = 0.001, momentum = 0.9)
exp_7_scheduler = optim.lr_scheduler.StepLR(optimizer_7, step_size = 7, gamma = 0.1)
model_7, statsDensenet = trainModel(model_7, 'densenet161', criterion, optimizer_7, exp_7_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.8150 Acc: 0.1998
# val Loss: 2.2040 Acc: 0.1923
#
# Epoch 1/14
# ----------
# train Loss: 1.6812 Acc: 0.2584
# val Loss: 1.6550 Acc: 0.3029
#
# Epoch 2/14
# ----------
# train Loss: 1.6229 Acc: 0.3014
# val Loss: 1.9444 Acc: 0.2260
#
# Epoch 3/14
# ----------
# train Loss: 1.5105 Acc: 0.4055
# val Loss: 1.9978 Acc: 0.2548
#
# Epoch 4/14
# ----------
# train Loss: 1.4033 Acc: 0.4258
# val Loss: 1.8993 Acc: 0.3269
#
# Epoch 5/14
# ----------
# train Loss: 1.2140 Acc: 0.5359
# val Loss: 2.0160 Acc: 0.2837
#
# Epoch 6/14
# ----------
# train Loss: 0.9999 Acc: 0.6112
# val Loss: 2.2130 Acc: 0.3365
#
# Epoch 7/14
# ----------
# train Loss: 0.5955 Acc: 0.7799
# val Loss: 1.9706 Acc: 0.4135
#
# Epoch 8/14
# ----------
# train Loss: 0.4483 Acc: 0.8589
# val Loss: 2.0014 Acc: 0.4375
#
# Epoch 9/14
# ----------
# ...

# %%
model_8 = models.densenet169(pretrained = True)
numClasses = 5
model_8.classifier = nn.Linear(1664, numClasses)
model_8 = model_8.to(device)
optimizer_8 = optim.SGD(model_8.parameters(), lr = 0.001, momentum = 0.9)
exp_8_scheduler = optim.lr_scheduler.StepLR(optimizer_8, step_size = 7, gamma = 0.1)
model_8, statsDensenet = trainModel(model_8, 'densenet169', criterion, optimizer_8, exp_8_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.8212 Acc: 0.2105
# val Loss: 1.8106 Acc: 0.2308
#
# Epoch 1/14
# ----------
# train Loss: 1.7230 Acc: 0.2548
# val Loss: 1.7125 Acc: 0.2404
#
# Epoch 2/14
# ----------
# train Loss: 1.6057 Acc: 0.3026
# val Loss: 1.7613 Acc: 0.2260
#
# Epoch 3/14
# ----------
# train Loss: 1.5105 Acc: 0.3624
# val Loss: 1.7188 Acc: 0.2885
#
# Epoch 4/14
# ----------
# train Loss: 1.3768 Acc: 0.4354
# val Loss: 1.9199 Acc: 0.2981
#
# Epoch 5/14
# ----------
# train Loss: 1.2793 Acc: 0.4976
# val Loss: 2.1766 Acc: 0.2981
#
# Epoch 6/14
# ----------
# train Loss: 1.1284 Acc: 0.5813
# val Loss: 2.0312 Acc: 0.3413
#
# Epoch 7/14
# ----------
# train Loss: 0.6781 Acc: 0.7823
# val Loss: 1.7182 Acc: 0.4038
#
# Epoch 8/14
# ----------
# train Loss: 0.4556 Acc: 0.8636
# val Loss: 1.7834 Acc: 0.4375
#
# Epoch 9/14
# ----------
# ...

# %%
model_9 = models.densenet201(pretrained = True)
numClasses = 5
model_9.classifier = nn.Linear(1920, numClasses)
model_9 = model_9.to(device)
optimizer_9 = optim.SGD(model_9.parameters(), lr = 0.001, momentum = 0.9)
exp_9_scheduler = optim.lr_scheduler.StepLR(optimizer_9, step_size = 7, gamma = 0.1)
model_9, stats = trainModel(model_9, 'densenet201', criterion, optimizer_9, exp_9_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.7825 Acc: 0.2261
# val Loss: 2.0422 Acc: 0.1635
#
# Epoch 1/14
# ----------
# train Loss: 1.7337 Acc: 0.2356
# val Loss: 1.8077 Acc: 0.3077
#
# Epoch 2/14
# ----------
# train Loss: 1.6469 Acc: 0.2871
# val Loss: 2.2506 Acc: 0.2500
#
# Epoch 3/14
# ----------
# train Loss: 1.5469 Acc: 0.3553
# val Loss: 2.0283 Acc: 0.1827
#
# Epoch 4/14
# ----------
# train Loss: 1.3988 Acc: 0.4462
# val Loss: 2.2906 Acc: 0.2692
#
# Epoch 5/14
# ----------
# train Loss: 1.3086 Acc: 0.5096
# val Loss: 3.3788 Acc: 0.3077
#
# Epoch 6/14
# ----------
# train Loss: 1.1091 Acc: 0.5849
# val Loss: 2.5347 Acc: 0.3221
#
# Epoch 7/14
# ----------
# train Loss: 0.6782 Acc: 0.7871
# val Loss: 2.5429 Acc: 0.3798
#
# Epoch 8/14
# ----------
# train Loss: 0.4485 Acc: 0.8600
# val Loss: 3.0499 Acc: 0.3654
#
# Epoch 9/14
# ----------
# ...

# %%
model_10 = models.densenet201(pretrained = True)
numClasses = 5
model_10.classifier = nn.Linear(1920, numClasses)
model_10 = model_10.to(device)
optimizer_10 = optim.SGD(model_10.parameters(), lr = 0.001, momentum = 0.9)
exp_10_scheduler = optim.lr_scheduler.StepLR(optimizer_10, step_size = 7, gamma = 0.1)
model_10, stats = trainModel(model_10, 'mobilenet', criterion, optimizer_10, exp_10_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.8249 Acc: 0.2356
# val Loss: 1.8725 Acc: 0.1923
#
# Epoch 1/14
# ----------
# train Loss: 1.7021 Acc: 0.2536
# val Loss: 2.0148 Acc: 0.2019
#
# Epoch 2/14
# ----------
# train Loss: 1.6349 Acc: 0.3026
# val Loss: 1.9478 Acc: 0.2885
#
# Epoch 3/14
# ----------
# train Loss: 1.5182 Acc: 0.3684
# val Loss: 1.6069 Acc: 0.3029
#
# Epoch 4/14
# ----------
# train Loss: 1.4577 Acc: 0.4366
# val Loss: 2.1123 Acc: 0.3317
#
# Epoch 5/14
# ----------
# train Loss: 1.2191 Acc: 0.5251
# val Loss: 2.0745 Acc: 0.2933
#
# Epoch 6/14
# ----------
# train Loss: 1.1982 Acc: 0.5383
# val Loss: 2.0270 Acc: 0.3317
#
# Epoch 7/14
# ----------
# train Loss: 0.6669 Acc: 0.7632
# val Loss: 1.8026 Acc: 0.4135
#
# Epoch 8/14
# ----------
# train Loss: 0.4631 Acc: 0.8481
# val Loss: 1.9066 Acc: 0.4327
#
# Epoch 9/14
# ----------
# ...

# %%
model_11 = models.alexnet(pretrained = True)
numClasses = 5
model_11.classifier[6] = nn.Linear(4096, numClasses)
model_11 = model_11.to(device)
optimizer_11 = optim.SGD(model_11.parameters(), lr = 0.001, momentum = 0.9)
exp_11_scheduler = optim.lr_scheduler.StepLR(optimizer_11, step_size = 7, gamma = 0.1)
model_11, stats = trainModel(model_11, 'alexnet', criterion, optimizer_11, exp_11_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.6174 Acc: 0.2225
# val Loss: 1.5969 Acc: 0.2356
#
# Epoch 1/14
# ----------
# train Loss: 1.5992 Acc: 0.2189
# val Loss: 1.5847 Acc: 0.2548
#
# Epoch 2/14
# ----------
# train Loss: 1.5973 Acc: 0.2572
# val Loss: 1.5905 Acc: 0.2260
#
# Epoch 3/14
# ----------
# train Loss: 1.5949 Acc: 0.2261
# val Loss: 1.6279 Acc: 0.2260
#
# Epoch 4/14
# ----------
# train Loss: 1.5892 Acc: 0.2428
# val Loss: 1.5807 Acc: 0.2644
#
# Epoch 5/14
# ----------
# train Loss: 1.5882 Acc: 0.2536
# val Loss: 1.5908 Acc: 0.2500
#
# Epoch 6/14
# ----------
# train Loss: 1.5865 Acc: 0.2560
# val Loss: 1.5864 Acc: 0.2452
#
# Epoch 7/14
# ----------
# train Loss: 1.5739 Acc: 0.2440
# val Loss: 1.5824 Acc: 0.2596
#
# Epoch 8/14
# ----------
# train Loss: 1.5606 Acc: 0.2596
# val Loss: 1.5846 Acc: 0.2500
#
# Epoch 9/14
# ----------
# ...

# %%
model_12 = models.vgg11(pretrained = True)
numClasses = 5
model_12.classifier[6] = nn.Linear(4096, numClasses)
model_12 = model_12.to(device)
optimizer_12 = optim.SGD(model_12.parameters(), lr = 0.001, momentum = 0.9)
exp_12_scheduler = optim.lr_scheduler.StepLR(optimizer_12, step_size = 7, gamma = 0.1)
model_12, stats = trainModel(model_12, 'vgg11', criterion, optimizer_12, exp_12_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.6272 Acc: 0.2105
# val Loss: 1.5894 Acc: 0.2404
#
# Epoch 1/14
# ----------
# train Loss: 1.6076 Acc: 0.2285
# val Loss: 1.5976 Acc: 0.2404
#
# Epoch 2/14
# ----------
# train Loss: 1.5968 Acc: 0.2416
# val Loss: 1.6254 Acc: 0.2115
#
# Epoch 3/14
# ----------
# train Loss: 1.6081 Acc: 0.2213
# val Loss: 1.5854 Acc: 0.2452
#
# Epoch 4/14
# ----------
# train Loss: 1.5983 Acc: 0.2225
# val Loss: 1.5949 Acc: 0.2356
#
# Epoch 5/14
# ----------
# train Loss: 1.5843 Acc: 0.2715
# val Loss: 1.5862 Acc: 0.2308
#
# Epoch 6/14
# ----------
# train Loss: 1.5781 Acc: 0.2990
# val Loss: 1.5727 Acc: 0.2837
#
# Epoch 7/14
# ----------
# train Loss: 1.5486 Acc: 0.3050
# val Loss: 1.5657 Acc: 0.2788
#
# Epoch 8/14
# ----------
# train Loss: 1.5248 Acc: 0.3397
# val Loss: 1.5598 Acc: 0.2933
#
# Epoch 9/14
# ----------
# ...

# %%
model_13 = models.vgg13(pretrained = True)
numClasses = 5
model_13.classifier[6] = nn.Linear(4096, numClasses)
model_13 = model_13.to(device)
optimizer_13 = optim.SGD(model_13.parameters(), lr = 0.001, momentum = 0.9)
exp_13_scheduler = optim.lr_scheduler.StepLR(optimizer_13, step_size = 7, gamma = 0.1)
model_13, stats = trainModel(model_13, 'vgg13', criterion, optimizer_13, exp_13_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.6316 Acc: 0.2069
# val Loss: 1.5883 Acc: 0.2692
#
# Epoch 1/14
# ----------
# train Loss: 1.6059 Acc: 0.2416
# val Loss: 1.5890 Acc: 0.2644
#
# Epoch 2/14
# ----------
# train Loss: 1.6001 Acc: 0.2404
# val Loss: 1.6014 Acc: 0.2500
#
# Epoch 3/14
# ----------
# train Loss: 1.6081 Acc: 0.2536
# val Loss: 1.5915 Acc: 0.2356
#
# Epoch 4/14
# ----------
# train Loss: 1.5976 Acc: 0.2213
# val Loss: 1.5749 Acc: 0.2837
#
# Epoch 5/14
# ----------
# train Loss: 1.5972 Acc: 0.2297
# val Loss: 1.5939 Acc: 0.2356
#
# Epoch 6/14
# ----------
# train Loss: 1.5858 Acc: 0.2512
# val Loss: 1.5884 Acc: 0.2837
#
# Epoch 7/14
# ----------
# train Loss: 1.5535 Acc: 0.3002
# val Loss: 1.5672 Acc: 0.2933
#
# Epoch 8/14
# ----------
# train Loss: 1.5394 Acc: 0.2907
# val Loss: 1.5573 Acc: 0.2933
#
# Epoch 9/14
# ----------
# ...

# %%
model_13 = models.vgg16(pretrained = True)
numClasses = 5
model_13.classifier[6] = nn.Linear(4096, numClasses)
model_13 = model_13.to(device)
optimizer_13 = optim.SGD(model_13.parameters(), lr = 0.001, momentum = 0.9)
exp_13_scheduler = optim.lr_scheduler.StepLR(optimizer_13, step_size = 7, gamma = 0.1)
model_13, stats = trainModel(model_13, 'vgg16', criterion, optimizer_13, exp_13_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.6226 Acc: 0.2321
# val Loss: 1.6583 Acc: 0.2356
#
# Epoch 1/14
# ----------
# train Loss: 1.6108 Acc: 0.2153
# val Loss: 1.5963 Acc: 0.2356
#
# Epoch 2/14
# ----------
# train Loss: 1.5985 Acc: 0.2213
# val Loss: 1.5879 Acc: 0.2596
#
# Epoch 3/14
# ----------
# train Loss: 1.5938 Acc: 0.2500
# val Loss: 1.5888 Acc: 0.2356
#
# Epoch 4/14
# ----------
# train Loss: 1.5825 Acc: 0.2524
# val Loss: 1.5722 Acc: 0.2260
#
# Epoch 5/14
# ----------
# train Loss: 1.5697 Acc: 0.2440
# val Loss: 1.5618 Acc: 0.2788
#
# Epoch 6/14
# ----------
# train Loss: 1.5622 Acc: 0.2763
# val Loss: 1.5384 Acc: 0.2885
#
# Epoch 7/14
# ----------
# train Loss: 1.4789 Acc: 0.3182
# val Loss: 1.5262 Acc: 0.2740
#
# Epoch 8/14
# ----------
# train Loss: 1.4377 Acc: 0.3636
# val Loss: 1.5052 Acc: 0.3269
#
# Epoch 9/14
# ----------
# ...

# %%
model_14 = models.googlenet(pretrained = True)
numClasses = 5
model_14.fc = nn.Linear(1024, numClasses)
model_14 = model_14.to(device)
optimizer_14 = optim.SGD(model_14.parameters(), lr = 0.001, momentum = 0.9)
exp_14_scheduler = optim.lr_scheduler.StepLR(optimizer_14, step_size = 7, gamma = 0.1)
model_14, stats = trainModel(model_14, 'googlenet', criterion, optimizer_14, exp_14_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.6760 Acc: 0.2404
# val Loss: 1.6106 Acc: 0.2596
#
# Epoch 1/14
# ----------
# train Loss: 1.6107 Acc: 0.2727
# val Loss: 1.6192 Acc: 0.2981
#
# Epoch 2/14
# ----------
# train Loss: 1.5484 Acc: 0.3218
# val Loss: 1.6996 Acc: 0.2548
#
# Epoch 3/14
# ----------
# train Loss: 1.4349 Acc: 0.3864
# val Loss: 1.6161 Acc: 0.3317
#
# Epoch 4/14
# ----------
# train Loss: 1.3191 Acc: 0.4522
# val Loss: 1.6457 Acc: 0.3173
#
# Epoch 5/14
# ----------
# train Loss: 1.1766 Acc: 0.5443
# val Loss: 1.8338 Acc: 0.3269
#
# Epoch 6/14
# ----------
# train Loss: 1.0621 Acc: 0.5694
# val Loss: 1.7174 Acc: 0.3990
#
# Epoch 7/14
# ----------
# train Loss: 0.6913 Acc: 0.7715
# val Loss: 1.5940 Acc: 0.4567
#
# Epoch 8/14
# ----------
# train Loss: 0.6287 Acc: 0.8050
# val Loss: 1.6036 Acc: 0.4038
#
# Epoch 9/14
# ----------
# ...

# %%
model_15 = models.vgg19(pretrained = True)
numClasses = 5
model_15.fc = nn.Linear(4096, numClasses)
model_15 = model_15.to(device)
optimizer_15 = optim.SGD(model_15.parameters(), lr = 0.001, momentum = 0.9)
exp_15_scheduler = optim.lr_scheduler.StepLR(optimizer_15, step_size = 7, gamma = 0.1)
model_15, stats = trainModel(model_15, 'vgg19', criterion, optimizer_15, exp_15_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: nan Acc: 0.2201
# val Loss: nan Acc: 0.2308
#
# Epoch 1/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 2/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 3/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 4/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 5/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 6/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 7/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 8/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 9/14
# ----------
# train Loss: nan Acc: 0.2261
# val Loss: nan Acc: 0.2308
#
# Epoch 10/14
# ...

# %%
model_16 = models.mnasnet0_5(pretrained = True)
numClasses = 5
model_16.classifier[1] = nn.Linear(1280, numClasses)
model_16 = model_16.to(device)
optimizer_16 = optim.SGD(model_16.parameters(), lr = 0.001, momentum = 0.9)
exp_16_scheduler = optim.lr_scheduler.StepLR(optimizer_16, step_size = 7, gamma = 0.1)
model_16, stats = trainModel(model_16, 'mnasnet0_5', criterion, optimizer_16, exp_16_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.6030 Acc: 0.2033
# val Loss: 1.5930 Acc: 0.2260
#
# Epoch 1/14
# ----------
# train Loss: 1.5984 Acc: 0.2273
# val Loss: 1.6007 Acc: 0.2356
#
# Epoch 2/14
# ----------
# train Loss: 1.5901 Acc: 0.2560
# val Loss: 1.5965 Acc: 0.2452
#
# Epoch 3/14
# ----------
# train Loss: 1.5794 Acc: 0.2799
# val Loss: 1.6118 Acc: 0.2067
#
# Epoch 4/14
# ----------
# train Loss: 1.5761 Acc: 0.2667
# val Loss: 1.6005 Acc: 0.2548
#
# Epoch 5/14
# ----------
# train Loss: 1.5743 Acc: 0.2799
# val Loss: 1.5924 Acc: 0.2404
#
# Epoch 6/14
# ----------
# train Loss: 1.5657 Acc: 0.2978
# val Loss: 1.6071 Acc: 0.2260
#
# Epoch 7/14
# ----------
# train Loss: 1.5583 Acc: 0.2751
# val Loss: 1.6082 Acc: 0.2404
#
# Epoch 8/14
# ----------
# train Loss: 1.5535 Acc: 0.3158
# val Loss: 1.6085 Acc: 0.2212
#
# Epoch 9/14
# ----------
# ...

# %%
model_17 = models.mnasnet1_0(pretrained = True)
numClasses = 5
model_17.classifier[1] = nn.Linear(1280, numClasses)
model_17 = model_16.to(device)
optimizer_17 = optim.SGD(model_17.parameters(), lr = 0.001, momentum = 0.9)
exp_17_scheduler = optim.lr_scheduler.StepLR(optimizer_17, step_size = 7, gamma = 0.1)
model_17, stats = trainModel(model_17, 'mnasnet1_0', criterion, optimizer_17, exp_17_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.5710 Acc: 0.2811
# val Loss: 1.6078 Acc: 0.2644
#
# Epoch 1/14
# ----------
# train Loss: 1.5615 Acc: 0.2943
# val Loss: 1.6215 Acc: 0.2260
#
# Epoch 2/14
# ----------
# train Loss: 1.5573 Acc: 0.3062
# val Loss: 1.6203 Acc: 0.2115
#
# Epoch 3/14
# ----------
# train Loss: 1.5482 Acc: 0.2955
# val Loss: 1.6345 Acc: 0.2115
#
# Epoch 4/14
# ----------
# train Loss: 1.5510 Acc: 0.3182
# val Loss: 1.6401 Acc: 0.2115
#
# Epoch 5/14
# ----------
# train Loss: 1.5369 Acc: 0.3206
# val Loss: 1.6334 Acc: 0.2115
#
# Epoch 6/14
# ----------
# train Loss: 1.5363 Acc: 0.3433
# val Loss: 1.6336 Acc: 0.2260
#
# Epoch 7/14
# ----------
# train Loss: 1.5364 Acc: 0.3421
# val Loss: 1.6338 Acc: 0.2212
#
# Epoch 8/14
# ----------
# train Loss: 1.5221 Acc: 0.3529
# val Loss: 1.6347 Acc: 0.2260
#
# Epoch 9/14
# ----------
# ...

# %%
model_18 = models.resnext101_32x8d(pretrained = True)
numClasses = 5
model_18.fc = nn.Linear(2048, numClasses)
model_18 = model_18.to(device)
optimizer_18 = optim.SGD(model_18.parameters(), lr = 0.001, momentum = 0.9)
exp_18_scheduler = optim.lr_scheduler.StepLR(optimizer_18, step_size = 7, gamma = 0.1)
model_18, stats = trainModel(model_18, 'resnet101_32x8d', criterion, optimizer_18, exp_18_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.7271 Acc: 0.1962
# val Loss: 1.6849 Acc: 0.2452
#
# Epoch 1/14
# ----------
# train Loss: 1.6108 Acc: 0.2560
# val Loss: 1.7029 Acc: 0.2452
#
# Epoch 2/14
# ----------
# train Loss: 1.5628 Acc: 0.2907
# val Loss: 1.6435 Acc: 0.2404
#
# Epoch 3/14
# ----------
# train Loss: 1.4933 Acc: 0.3565
# val Loss: 1.6887 Acc: 0.2596
#
# Epoch 4/14
# ----------
# train Loss: 1.3670 Acc: 0.4378
# val Loss: 2.1819 Acc: 0.2933
#
# Epoch 5/14
# ----------
# train Loss: 1.2119 Acc: 0.5502
# val Loss: 1.6869 Acc: 0.3702
#
# Epoch 6/14
# ----------
# train Loss: 1.0729 Acc: 0.5873
# val Loss: 1.6737 Acc: 0.3606
#
# Epoch 7/14
# ----------
# train Loss: 0.6508 Acc: 0.7895
# val Loss: 1.5261 Acc: 0.4375
#
# Epoch 8/14
# ----------
# train Loss: 0.4130 Acc: 0.8684
# val Loss: 1.6404 Acc: 0.4615
#
# Epoch 9/14
# ----------
# ...

# %%
models.resnext50_32x4d(pretrained = True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to C:\Users\Patrick/.cache\torch\checkpoints\resnext50_32x4d-7cdf4587.pth
# 100%|██████████████████████████████████████████████████████████████████████████████| 95.8M/95.8M [09:29<00:00, 176kB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
# ...

# %%
model_19 = models.resnext50_32x4d(pretrained = True)
numClasses = 5
model_19.fc = nn.Linear(2048, numClasses)
model_19 = model_19.to(device)
optimizer_19 = optim.SGD(model_19.parameters(), lr = 0.001, momentum = 0.9)
exp_19_scheduler = optim.lr_scheduler.StepLR(optimizer_19, step_size = 7, gamma = 0.1)
model_19, stats = trainModel(model_19, 'resnext50_32x4d', criterion, optimizer_19, exp_19_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.8488 Acc: 0.2153
# val Loss: 1.8476 Acc: 0.2067
#
# Epoch 1/14
# ----------
# train Loss: 1.7455 Acc: 0.2584
# val Loss: 1.7027 Acc: 0.2500
#
# Epoch 2/14
# ----------
# train Loss: 1.6183 Acc: 0.2978
# val Loss: 1.7081 Acc: 0.2788
#
# Epoch 3/14
# ----------
# train Loss: 1.4970 Acc: 0.3935
# val Loss: 1.6614 Acc: 0.3173
#
# Epoch 4/14
# ----------
# train Loss: 1.3668 Acc: 0.4510
# val Loss: 1.6980 Acc: 0.3846
#
# Epoch 5/14
# ----------
# train Loss: 1.1351 Acc: 0.5526
# val Loss: 2.3276 Acc: 0.3125
#
# Epoch 6/14
# ----------
# train Loss: 1.0850 Acc: 0.5730
# val Loss: 2.0398 Acc: 0.4038
#
# Epoch 7/14
# ----------
# train Loss: 0.6430 Acc: 0.7775
# val Loss: 1.8568 Acc: 0.4615
#
# Epoch 8/14
# ----------
# train Loss: 0.4325 Acc: 0.8768
# val Loss: 1.9431 Acc: 0.4423
#
# Epoch 9/14
# ----------
# ...

# %%
model_20 = models.shufflenet_v2_x0_5(pretrained = True)
numClasses = 5
model_20.fc = nn.Linear(1024, numClasses)
model_20 = model_20.to(device)
optimizer_20 = optim.SGD(model_20.parameters(), lr = 0.001, momentum = 0.9)
exp_20_scheduler = optim.lr_scheduler.StepLR(optimizer_20, step_size = 7, gamma = 0.1)
model_20, stats = trainModel(model_20, 'shufflenet_v2_x0_5', criterion, optimizer_20, exp_20_scheduler)
# Out:
# Training stage:512
# Directory C:\Users\Patrick\Documents\GitHub\ICDeepLearning\Data\GAF_PCA\512 loaded successfully.
# Epoch 0/14
# ----------
# train Loss: 1.6048 Acc: 0.2105
# val Loss: 1.5992 Acc: 0.2163
#
# Epoch 1/14
# ----------
# train Loss: 1.5986 Acc: 0.2069
# val Loss: 1.5950 Acc: 0.1923
#
# Epoch 2/14
# ----------
# train Loss: 1.5954 Acc: 0.2117
# val Loss: 1.5930 Acc: 0.2212
#
# Epoch 3/14
# ----------
# train Loss: 1.5946 Acc: 0.2261
# val Loss: 1.5918 Acc: 0.2163
#
# Epoch 4/14
# ----------
# train Loss: 1.5938 Acc: 0.2392
# val Loss: 1.5914 Acc: 0.2500
#
# Epoch 5/14
# ----------
# train Loss: 1.5923 Acc: 0.2404
# val Loss: 1.5913 Acc: 0.2308
#
# Epoch 6/14
# ----------
# train Loss: 1.5922 Acc: 0.2500
# val Loss: 1.5904 Acc: 0.2019
#
# Epoch 7/14
# ----------
# train Loss: 1.5906 Acc: 0.2691
# val Loss: 1.5906 Acc: 0.2212
#
# Epoch 8/14
# ----------
# train Loss: 1.5915 Acc: 0.2632
# val Loss: 1.5904 Acc: 0.2019
#
# Epoch 9/14
# ----------
# ...

# %%
models.shufflenet_v2_x1_0(pretrained = True)
# Out:
# Downloading: "https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth" to C:\Users\Patrick/.cache\torch\checkpoints\shufflenetv2_x1-5666bf0f80.pth
# 100%|██████████████████████████████████████████████████████████████████████████████| 8.79M/8.79M [00:31<00:00, 292kB/s]
# ShuffleNetV2(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (stage2): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(24, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...
